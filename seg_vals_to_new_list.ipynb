# %%
cd /Users/vicky/Desktop/CitPy/citpy_analysis
# Out:
# /Users/vicky/Desktop/CitPy/citpy_analysis

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('classifications.csv')

# %%
data = data[:200]

# %%
data
# Out:
#      classification_id                           user_name    user_id  \
# 0             29905097  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 1             30252949  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 2             30298705  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 3             30299339  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 4             30299347  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 5             30300261  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 6             30380376  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 7             30381722  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 8             30408630  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 9             30418906  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 10            30438129  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 11            31074072  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 12            31124696  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 13            31173577  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 14            31175443  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 15            31176981  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 16            31184143  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 17            31352367  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 18            31364105  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 19            31365282  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 20            31365344  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 21            31368611  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 22            31377675                 fieldmuseumexhibits  1526226.0
# 23            31380650  not-logged-in-c9f87ea6dca2d92c2aa6        NaN
# 24            31380680  not-logged-in-c9f87ea6dca2d92c2aa6        NaN
# 25            31414859  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 26            31415037  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 27            31415100  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 28            31415182  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 29            31415272  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# ..                 ...                                 ...        ...
# 170           32902334  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 171           32902422  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 172           32903436  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 173           32903472  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 174           32903512  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 175           32904205  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 176           32904291  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 177           32915105  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 178           32915420  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 179           32915883  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 180           32916172  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 181           32917745  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 182           32917955  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 183           32919847  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 184           32920057  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 185           32920197  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 186           32920347  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 187           32929300  not-logged-in-309cf7dc8a4a295d98a5        NaN
# 188           32929394  not-logged-in-309cf7dc8a4a295d98a5        NaN
# 189           32949285  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 190           32954286  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 191           32955868  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 192           32957026  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 193           32973923  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 194           32974448  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 195           32974540  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 196           32974599  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 197           32974652  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 198           32989021  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 199           32990543  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
#
#                   user_ip  workflow_id   workflow_name  workflow_version  \
# 0    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.5
# 1    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.5
# 2    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 3    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 4    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 5    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 6    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 7    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 8    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 9    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 10   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 11   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 12   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 13   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 14   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 15   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 16   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 17   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 18   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 19   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 20   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 21   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 22   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 23   c9f87ea6dca2d92c2aa6         3449  Measure Leaves               5.8
# 24   c9f87ea6dca2d92c2aa6         3449  Measure Leaves               5.8
# 25   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 26   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 27   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 28   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 29   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# ..                    ...          ...             ...               ...
# 170  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 171  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 172  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 173  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 174  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 175  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 176  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 177  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 178  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 179  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 180  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 181  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 182  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 183  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 184  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 185  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 186  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 187  309cf7dc8a4a295d98a5         3449  Measure Leaves               5.8
# 188  309cf7dc8a4a295d98a5         3449  Measure Leaves               5.8
# 189  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 190  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 191  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 192  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 193  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 194  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 195  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 196  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 197  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 198  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 199  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
#
#                   created_at  gold_standard  expert  \
# 0    2017-02-24 22:40:36 UTC            NaN     NaN
# 1    2017-02-27 16:05:05 UTC            NaN     NaN
# 2    2017-02-27 22:11:54 UTC            NaN     NaN
# 3    2017-02-27 22:16:37 UTC            NaN     NaN
# 4    2017-02-27 22:16:40 UTC            NaN     NaN
# 5    2017-02-27 22:22:36 UTC            NaN     NaN
# 6    2017-02-28 16:03:13 UTC            NaN     NaN
# 7    2017-02-28 16:14:48 UTC            NaN     NaN
# 8    2017-02-28 17:02:24 UTC            NaN     NaN
# 9    2017-02-28 17:14:42 UTC            NaN     NaN
# 10   2017-02-28 17:40:37 UTC            NaN     NaN
# 9    [{"task":"T0","task_label":"Drag your finger t...
# 10   [{"task":"T0","task_label":"Drag your finger t...
# 11   [{"task":"T0","task_label":"Drag your finger t...
# 12   [{"task":"T0","task_label":"Drag your finger t...
# 13   [{"task":"T0","task_label":"Drag your finger t...
# 14   [{"task":"T0","task_label":"Drag your finger t...
# 15   [{"task":"T0","task_label":"Drag your finger t...
# 16   [{"task":"T0","task_label":"Drag your finger t...
# 17   [{"task":"T0","task_label":"Drag your finger t...
# 18   [{"task":"T0","task_label":"Drag your finger t...
# 19   [{"task":"T0","task_label":"Drag your finger t...
# 20   [{"task":"T0","task_label":"Drag your finger t...
# 21   [{"task":"T0","task_label":"Drag your finger t...
# 22   [{"task":"T0","task_label":"Drag your finger t...
# 23   [{"task":"T0","task_label":"Drag your finger t...
# 24   [{"task":"T0","task_label":"Drag your finger t...
# 25   [{"task":"T0","task_label":"Drag your finger t...
# 26   [{"task":"T0","task_label":"Drag your finger t...
# 27   [{"task":"T0","task_label":"Drag your finger t...
# 28   [{"task":"T0","task_label":"Drag your finger t...
# 29   [{"task":"T0","task_label":"Drag your finger t...
# ..                                                 ...
# 170  [{"task":"T0","task_label":"Drag your finger t...
# 171  [{"task":"T0","task_label":"Drag your finger t...
# 172  [{"task":"T0","task_label":"Drag your finger t...
# 173  [{"task":"T0","task_label":"Drag your finger t...
# 174  [{"task":"T0","task_label":"Drag your finger t...
# 175  [{"task":"T0","task_label":"Drag your finger t...
# 176  [{"task":"T0","task_label":"Drag your finger t...
# 177  [{"task":"T0","task_label":"Drag your finger t...
# 178  [{"task":"T0","task_label":"Drag your finger t...
# 179  [{"task":"T0","task_label":"Drag your finger t...
# 180  [{"task":"T0","task_label":"Drag your finger t...
# 181  [{"task":"T0","task_label":"Drag your finger t...
# 182  [{"task":"T0","task_label":"Drag your finger t...
# 183  [{"task":"T0","task_label":"Drag your finger t...
# 184  [{"task":"T0","task_label":"Drag your finger t...
# 185  [{"task":"T0","task_label":"Drag your finger t...
# 186  [{"task":"T0","task_label":"Drag your finger t...
# 187  [{"task":"T0","task_label":"Drag your finger t...
# 188  [{"task":"T0","task_label":"Drag your finger t...
# 189  [{"task":"T0","task_label":"Drag your finger t...
# 190  [{"task":"T0","task_label":"Drag your finger t...
# 191  [{"task":"T0","task_label":"Drag your finger t...
# 192  [{"task":"T0","task_label":"Drag your finger t...
# 193  [{"task":"T0","task_label":"Drag your finger t...
# 194  [{"task":"T0","task_label":"Drag your finger t...
# 195  [{"task":"T0","task_label":"Drag your finger t...
# 196  [{"task":"T0","task_label":"Drag your finger t...
# 197  [{"task":"T0","task_label":"Drag your finger t...
# 198  [{"task":"T0","task_label":"Drag your finger t...
# 199  [{"task":"T0","task_label":"Drag your finger t...
#
#                                           subject_data  subject_ids
# 0    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 1    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 2    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 3    {"6262370":{"retired":null,"latitude":"-37.553...      6262370
# 190  {"6262410":{"retired":null,"latitude":"-40.967...      6262410
# 191  {"6262381":{"retired":null,"latitude":"-41.335...      6262381
# 192  {"6262358":{"retired":null,"latitude":"","long...      6262358
# 193  {"6262410":{"retired":null,"latitude":"-40.967...      6262410
# 194  {"6262409":{"retired":null,"latitude":"-40.967...      6262409
# 195  {"6262396":{"retired":null,"latitude":"-40.967...      6262396
# 196  {"6262339":{"retired":null,"latitude":"","long...      6262339
# 197  {"6262401":{"retired":null,"latitude":"-40.967...      6262401
# 198  {"6262360":{"retired":null,"latitude":"-29.267...      6262360
# 199  {"6262409":{"retired":null,"latitude":"-40.967...      6262409
#
# [200 rows x 14 columns]

# %%
def vals_to_new_column(data_column):
    """
    takes the data.annotations column as a parameter
    returns dataframe with individual segment coordinates stored in a row
    """
    list_vals = []
    for entry in json.loads(data_column)[0]['value']:
        list_vals.append([entry['x1'], entry['y1'], entry['x2'], entry['y2']])
    return list_vals

data['listed_vals'] = data['annotations'].apply(vals_to_new_column)

# %%
data['listed_vals'] = data['annotations'].apply(vals_to_new_column)

# %%
data
# Out:
#      classification_id                           user_name    user_id  \
# 0             29905097  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 1             30252949  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 2             30298705  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 3             30299339  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 4             30299347  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 5             30300261  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 6             30380376  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 7             30381722  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 8             30408630  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 9             30418906  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 10            30438129  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 11            31074072  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 12            31124696  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 13            31173577  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 14            31175443  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 15            31176981  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 16            31184143  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 17            31352367  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 18            31364105  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 19            31365282  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 20            31365344  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 21            31368611  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 22            31377675                 fieldmuseumexhibits  1526226.0
# 23            31380650  not-logged-in-c9f87ea6dca2d92c2aa6        NaN
# 24            31380680  not-logged-in-c9f87ea6dca2d92c2aa6        NaN
# 25            31414859  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 26            31415037  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 27            31415100  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 28            31415182  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 29            31415272  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# ..                 ...                                 ...        ...
# 170           32902334  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 171           32902422  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 172           32903436  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 173           32903472  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 174           32903512  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 175           32904205  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 176           32904291  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 177           32915105  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 178           32915420  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 179           32915883  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 180           32916172  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 181           32917745  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 182           32917955  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 183           32919847  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 184           32920057  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 185           32920197  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 186           32920347  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 187           32929300  not-logged-in-309cf7dc8a4a295d98a5        NaN
# 188           32929394  not-logged-in-309cf7dc8a4a295d98a5        NaN
# 189           32949285  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 190           32954286  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 191           32955868  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 192           32957026  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 193           32973923  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 194           32974448  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 195           32974540  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 196           32974599  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 197           32974652  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 198           32989021  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
# 199           32990543  not-logged-in-3dfa3cd88ac5a4508e6c        NaN
#
#                   user_ip  workflow_id   workflow_name  workflow_version  \
# 0    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.5
# 1    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.5
# 2    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 3    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 4    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 5    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 6    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 7    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 8    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 9    3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 10   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 11   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 12   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 13   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 14   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 15   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 16   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 17   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 18   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 19   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 20   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 21   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 22   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 23   c9f87ea6dca2d92c2aa6         3449  Measure Leaves               5.8
# 24   c9f87ea6dca2d92c2aa6         3449  Measure Leaves               5.8
# 25   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 26   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 27   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 28   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 29   3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# ..                    ...          ...             ...               ...
# 170  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 171  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 172  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 173  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 174  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 175  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 176  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 177  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 178  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 179  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 180  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
# 181  3dfa3cd88ac5a4508e6c         3449  Measure Leaves               5.8
#
{"session":"e92b02381c8564a2c3e23e51f735daca01...
# 180  {"session":"e92b02381c8564a2c3e23e51f735daca01...
# 181  {"session":"400c76b93c3e0170d7b346ed8fb47194ab...
# 182  {"session":"400c76b93c3e0170d7b346ed8fb47194ab...
# 183  {"session":"e7427721025efa43279e6ef6da4d992519...
# 184  {"session":"e7427721025efa43279e6ef6da4d992519...
# 185  {"session":"e7427721025efa43279e6ef6da4d992519...
# 186  {"session":"e7427721025efa43279e6ef6da4d992519...
# 187  {"session":"e27c98d038598db49536dd9f0ae5663c6c...
# 188  {"session":"e27c98d038598db49536dd9f0ae5663c6c...
# 189  {"session":"c16db02b895ec0361c0381d19149254e46...
# 190  {"session":"972c860c822ede7c0a8bf24dbfcbf7838d...
# 191  {"session":"d3face9c00e3324a80efce769603199969...
# 192  {"session":"d9a44b8477b50f71da65c080a8e32d7e72...
# 193  {"session":"715af87f93b70484c501f4e7bbc76c5c1a...
# 194  {"session":"fe3c4aafb0ca888a5f126731d80089dcf1...
# 195  {"session":"fe3c4aafb0ca888a5f126731d80089dcf1...
# 196  {"session":"fe3c4aafb0ca888a5f126731d80089dcf1...
# 197  {"session":"fe3c4aafb0ca888a5f126731d80089dcf1...
# 198  {"session":"56f8397470736f98bf8885a85c3537da2a...
# 199  {"session":"b497b116365757bc306360b366df1a289d...
#
#                                            annotations  \
# 0    [{"task":"T0","task_label":"Draw a line to mar...
# 1    [{"task":"T0","task_label":"Draw a line to mar...
# 2    [{"task":"T0","task_label":"Drag your finger t...
# 3    [{"task":"T0","task_label":"Drag your finger t...
# 4    [{"task":"T0","task_label":"Drag your finger t...
# 5    [{"task":"T0","task_label":"Drag your finger t...
# 6    [{"task":"T0","task_label":"Drag your finger t...
# 7    [{"task":"T0","task_label":"Drag your finger t...
# 8    [{"task":"T0","task_label":"Drag your finger t...
# 9    [{"task":"T0","task_label":"Drag your finger t...
# 10   [{"task":"T0","task_label":"Drag your finger t...
# 11   [{"task":"T0","task_label":"Drag your finger t...
# 12   [{"task":"T0","task_label":"Drag your finger t...
# 13   [{"task":"T0","task_label":"Drag your finger t...
# 14   [{"task":"T0","task_label":"Drag your finger t...
# 15   [{"task":"T0","task_label":"Drag your finger t...
# 16   [{"task":"T0","task_label":"Drag your finger t...
# 17   [{"task":"T0","task_label":"Drag your finger t...
# 18   [{"task":"T0","task_label":"Drag your finger t...
# 19   [{"task":"T0","task_label":"Drag your finger t...
# 20   [{"task":"T0","task_label":"Drag your finger t...
# 21   [{"task":"T0","task_label":"Drag your finger t...
# 22   [{"task":"T0","task_label":"Drag your finger t...
# 23   [{"task":"T0","task_label":"Drag your finger t...
# 24   [{"task":"T0","task_label":"Drag your finger t...
# 25   [{"task":"T0","task_label":"Drag your finger t...
# 26   [{"task":"T0","task_label":"Drag your finger t...
# 27   [{"task":"T0","task_label":"Drag your finger t...
# 28   [{"task":"T0","task_label":"Drag your finger t...
# 29   [{"task":"T0","task_label":"Drag your finger t...
# ..                                                 ...
# 170  [{"task":"T0","task_label":"Drag your finger t...
# 171  [{"task":"T0","task_label":"Drag your finger t...
# 172  [{"task":"T0","task_label":"Drag your finger t...
# 173  [{"task":"T0","task_label":"Drag your finger t...
# 174  [{"task":"T0","task_label":"Drag your finger t...
# 175  [{"task":"T0","task_label":"Drag your finger t...
# 176  [{"task":"T0","task_label":"Drag your finger t...
# 177  [{"task":"T0","task_label":"Drag your finger t...
# 178  [{"task":"T0","task_label":"Drag your finger t...
# 179  [{"task":"T0","task_label":"Drag your finger t...
# 180  [{"task":"T0","task_label":"Drag your finger t...
# 181  [{"task":"T0","task_label":"Drag your finger t...
# 182  [{"task":"T0","task_label":"Drag your finger t...
# 183  [{"task":"T0","task_label":"Drag your finger t...
# 184  [{"task":"T0","task_label":"Drag your finger t...
# 185  [{"task":"T0","task_label":"Drag your finger t...
# 186  [{"task":"T0","task_label":"Drag your finger t...
# 187  [{"task":"T0","task_label":"Drag your finger t...
# 188  [{"task":"T0","task_label":"Drag your finger t...
# 189  [{"task":"T0","task_label":"Drag your finger t...
# 190  [{"task":"T0","task_label":"Drag your finger t...
# 191  [{"task":"T0","task_label":"Drag your finger t...
# 192  [{"task":"T0","task_label":"Drag your finger t...
# 193  [{"task":"T0","task_label":"Drag your finger t...
# 194  [{"task":"T0","task_label":"Drag your finger t...
# 195  [{"task":"T0","task_label":"Drag your finger t...
# 196  [{"task":"T0","task_label":"Drag your finger t...
# 197  [{"task":"T0","task_label":"Drag your finger t...
# 198  [{"task":"T0","task_label":"Drag your finger t...
# 199  [{"task":"T0","task_label":"Drag your finger t...
#
#                                           subject_data  subject_ids  \
# 0    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 1    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 2    {"5653194":{"retired":null,"Filename":"9511_si...      5653194
# 3    {"6262370":{"retired":null,"latitude":"-37.553...      6262370
# 4    {"6262339":{"retired":null,"latitude":"","long...      6262339
# 5    {"6262403":{"retired":null,"latitude":"-40.967...      6262403
# 6    {"6262372":{"retired":null,"latitude":"-37.553...      6262372
# 7    {"6262362":{"retired":null,"latitude":"-29.267...      6262362
# 8    {"6262363":{"retired":null,"latitude":"-29.267...      6262363
# 9    {"6262405":{"retired":null,"latitude":"-40.967...      6262405
# 10   {"6262392":{"retired":null,"latitude":"-40.967...      6262392
# 11   {"6262343":{"retired":null,"latitude":"-55.032...      6262343
# 12   {"6262362":{"retired":null,"latitude":"-29.267...      6262362
# 13   {"6262398":{"retired":null,"latitude":"-40.967...      6262398
# 14   {"6262371":{"retired":null,"latitude":"-37.553...      6262371
# 15   {"6262397":{"retired":null,"latitude":"-40.967...      6262397
# 16   {"6262366":{"retired":null,"latitude":"","long...      6262366
# 17   {"6262341":{"retired":null,"latitude":"-54.700...      6262341
# 18   {"6262359":{"retired":null,"latitude":"-29.267...      6262359
# 19   {"6262343":{"retired":null,"latitude":"-55.032...      6262343
# 20   {"6262349":{"retired":null,"latitude":"-54.954...      6262349
# 21   {"6262350":{"retired":null,"latitude":"-54.892...      6262350
# 22   {"6262389":{"retired":null,"latitude":"-40.967...      6262389
# 23   {"6262407":{"retired":null,"latitude":"-40.967...      6262407
# 24   {"6262350":{"retired":null,"latitude":"-54.892...      6262350
# 25   {"6262339":{"retired":null,"latitude":"","long...      6262339
# 26   {"6262382":{"retired":null,"latitude":"-41.335...      6262382
# 27   {"6262390":{"retired":null,"latitude":"-40.967...      6262390
# 28   {"6262396":{"retired":null,"latitude":"-40.967...      6262396
# 29   {"6262362":{"retired":null,"latitude":"-29.267...      6262362
# ..                                                 ...          ...
# 24   [[465.45294189453125, 111.00308227539062, 380....
# 25        [[294, 158, 485, 239], [364, 239, 395, 140]]
# 26   [[487, 298, 621, 396], [515, 369, 567, 303], [...
# 27        [[214, 224, 186, 394], [157, 300, 240, 313]]
# 28         [[495, 47, 496, 219], [452, 132, 532, 133]]
# 29   [[430, 22, 424, 151], [393, 92, 451, 95], [710...
# ..                                                 ...
# 170  [[553, 214, 616, 332], [626, 238, 542, 275], [...
# 171  [[117, 24, 60, 182], [44, 104, 112, 126], [262...
# 172                                                 []
# 173       [[445, 113, 296, 233], [354, 111, 431, 188]]
# 174       [[284, 346, 376, 348], [330, 285, 323, 478]]
# 175                             [[449, 266, 449, 383]]
# 176                             [[552, 146, 521, 310]]
# 177       [[198, 214, 192, 401], [149, 302, 249, 281]]
# 178  [[258, 311, 392, 413], [518, 377, 566, 292], [...
# 179  [[61, 180, 233, 253], [158, 272, 195, 174], [4...
# 180  [[413, 290, 502, 151], [402, 229, 481, 270], [...
# 181  [[449, 86, 379, 219], [362, 133, 480, 136], [2...
# 182  [[552, 212, 418, 296], [469, 208, 518, 281], [...
# 183         [[207, 22, 253, 184], [189, 112, 271, 89]]
# 184  [[408, 301, 557, 205], [472, 196, 533, 283], [...
# 185  [[163, 318, 322, 239], [232, 228, 275, 311], [...
# 186  [[525, 257, 635, 347], [571, 347, 627, 297], [...
# 187  [[343.34954833984375, 284.9079284667969, 337.7...
# 188  [[348.8996887207031, 164.65457153320312, 322.9...
# 189  [[185, 275, 187, 348], [123, 313, 253, 307], [...
# 190  [[166, 254, 49, 358], [79, 267, 152, 341], [65...
# 191  [[416, 412, 332, 465], [323, 376, 422, 510], [...
# 192  [[654, 191, 616, 246], [662, 183, 609, 252], [...
# 193  [[577, 256, 639, 325], [664, 242, 535, 340], [...
# 194  [[279, 194, 460, 192], [362, 153, 368, 251], [...
# 195  [[480, 54, 502, 224], [448, 157, 533, 134], [1...
# 196       [[290, 161, 494, 263], [375, 249, 433, 174]]
# 197        [[160, 116, 123, 282], [99, 188, 178, 200]]
# 198  [[142, 24, 151, 157], [108, 92, 188, 88], [237...
# 199                                                 []
#
# [200 rows x 15 columns]

# %%
def classification_raw_number(uncleaned_data):
    total = 0
    for row in range(len(uncleaned_data)):
        row_classifications = 0
        if len(uncleaned_data.listed_vals[row]) > 1:
            if len(uncleaned_data.listed_vals[row])% 2==0:
                row_classifications += len(uncleaned_data.listed_vals[row])/2
            else:
                row_classifications += (len(uncleaned_data.listed_vals[row])/2) -1
            print(row_classifications)
            total += row_classifications
    return total

# %%
#other interesting things to look at:

# 1. number of attempted lobule classifications per subject image - 
    # if consistent, all lobules in subject image are probably clear and obvious
    
# 2. clustered intersections / major and minor axes for given subject image

# 3. think about necessary retirement counts
    # how many classifications of a given lobule are necessary to gain accurate analysis
    
# 4. machine learning - how can we use it.

# %%
import numpy as np
import math

class Segment:
    def __init__(self, x1, y1, x2, y2):
        self.x1 = x1
        self.y1 = y1
        self.x2 = x2
        self.y2 = y2
        self.minx=0 #screen dimensions
        self.maxx=720 #screen dimensions
        self.miny=0 #screen dimensions
        self.maxy=534 #screen dimensions
        self.tolerance=5 #allowed distance from the edge
        
    def point_on_screen(self):
        if ((self.minx-self.tolerance <= self.x1 <= self.maxx+self.tolerance) and \
             (self.minx-self.tolerance <= self.x2 <= self.maxx+self.tolerance) and \
             (self.miny-self.tolerance <= self.y1 <= self.maxy+self.tolerance) and \
             (self.miny-self.tolerance <= self.y2 <= self.maxy+self.tolerance)):
             return True
        else:
             return False

    def find_line_equation(self):
        A = self.y1 - self.y2
        B = self.x2 - self.x1 
        C = A * self.x1 + B * self.y1 
        return_list: List[Any] = [A, B, C]
        return return_list
    

class CheckLeaf:
    def __init__(self, segA, segB):
        self.segA = segA
        self.segB = segB
        self.segclassA = Segment(segA[0],segA[1],segA[2],segA[3])
        self.segclassB = Segment(segB[0],segB[1],segB[2],segB[3])
        self.coefficients_a = self.segclassA.find_line_equation()
        self.coefficients_b = self.segclassB.find_line_equation()
        self.x1_a = segA[0]
        self.y1_a = segA[1]
        self.x2_a = segA[2]
        self.y2_a = segA[3]
        self.x1_b = segB[0]
        self.y1_b = segB[1]
        self.x2_b = segB[2]
        self.y2_b = segB[3]
        
    def on_screen(self):
        if self.segclassA.point_on_screen() and self.segclassB.point_on_screen():
            return True
        else:
            return False

    def find_the_intersection_point(self):
        coefficient_matrix = np.matrix([[self.coefficients_a[0], self.coefficients_a[1]], [self.coefficients_b[0], self.coefficients_b[1]]])
        RHS_matrix = np.matrix([[self.coefficients_a[2]], [self.coefficients_b[2]]])
        det = np.linalg.det(coefficient_matrix)
        if (det ** 2 > 0.00000001):
            # in this case, the segments intersect somewhere
            inverse_coefficient_matrix = coefficient_matrix.I
            solution = inverse_coefficient_matrix.dot(RHS_matrix)
            return solution
        else:
            # in this case, the lines are essentially parallel, so they will not intersect on screen, if at all.  I've put in a fake point which will fail a later llogic check.
            return ([-1000000, -1000000])

    def line_segments_intersect(self):
        det = np.linalg.det(np.matrix([[self.coefficients_a[0], self.coefficients_a[1]], [self.coefficients_b[0], self.coefficients_b[1]]]))
        if (det ** 2 > 0.0001):
            intersection_point = self.find_the_intersection_point()
            # find boundaries of the line segments.
            min_ax = int(min(self.x1_a, self.x2_a));
            max_ax = int(max(self.x1_a, self.x2_a))
            min_ay = int(min(self.y1_a, self.y2_a));
            max_ay = int(max(self.y1_a, self.y2_a))
            min_bx = int(min(self.x1_b, self.x2_b));
            max_bx = int(max(self.x1_b, self.x2_b))
            min_by = int(min(self.y1_b, self.y2_b));
            max_by = int(max(self.y1_b, self.y2_b))
            # If the intersection is within the boundaries
            # defined by the most extreme values of the coordinates then we can be assured that the
            # line segments actually do intersect. The following if statement returns the necessary
            # TRUE or FALSE that we want to see in order to move on.
            if ((min_ax <= intersection_point[0] <= max_ax) and \
                    (min_ay <= intersection_point[1] <= max_ay) and \
                    (min_bx <= intersection_point[0] <= max_bx) and \
                    (min_by <= intersection_point[1] <= max_by)):
                return True
            else:
                return False
        else:
            return False # a determinent of zero means the line segments are parallel.
        
    def calc_slopes(self):
        slope1 = (self.y1_a - self.y2_a) / (self.x1_a - self.x2_a) if (self.x1_a - self.x2_a) != 0 else 0.0
        slope2 = (self.y1_b - self.y2_b) / (self.x1_b - self.x2_b) if (self.x1_b - self.x2_b) != 0 else 0.0
        return slope1, slope2

    def calc_angle_between_segments(self):
            slope1, slope2 = self.calc_slopes()
            numerator = (slope2 - slope1)
            denominator = (1 + slope2 * slope1)
            if denominator == 0:
                return 90.0
            else:
                return ((math.atan(numerator / denominator) * 180 / math.pi))

    def calc_lengths_minor_major(self):
        """
        returns: 0 - major axis length, 1 - major axis coordinates, 2 - minor axis length, 3 - minor axis coordinates
        """
        length_axis1 = math.sqrt(abs(self.y1_a - self.y2_a) ** 2 + abs(self.x1_a - self.x2_a) ** 2)
        length_axis2 = math.sqrt(abs(self.y1_b - self.y2_b) ** 2 + abs(self.x1_b - self.x2_b) ** 2)
        if length_axis1 > length_axis2:
            return length_axis1, self.segA, length_axis2, self.segB
        else:
            return length_axis2, self.segB, length_axis1, self.segA

# %%
#tests
#90 angles
testangle90 = CheckLeaf([0,0,4,4],[0,4,4,0])
testanglevertslope = CheckLeaf([4,0,4,4], [0,2,6,2])

# %%
print(testangle90.coefficients_a)
print(testangle90.calc_angle_between_segments())
print(testangle90.calc_lengths_minor_major())
# Out:
# [-4, 4, 0]
# 90.0
# (5.656854249492381, [0, 4, 4, 0], 5.656854249492381, [0, 0, 4, 4])

# %%
testanglevertslope.calc_slopes()
testanglevertslope.calc_angle_between_segments()
# Out:
# -0.0

# %%
import itertools

def make_plant_datasheet(data_table):
    """
    takes the datasheet with 'listed_vals' column as a parameter
    returns dataframe with useful metadata, angle, axis length and axis coordinates.
    """
    df = pd.DataFrame() #columns = [0: 'classification_id', 'username', 'created_at', 'subject_data' , 'angle', 'major_axis_length', 'x1_major', 'x2_major', 'y1_major', 'y2_major', 'minor_axis_length', 'x1_minor', 'x2_minor', 'y1_minor', 'y2_minor'] (will rename at end)
    for row_num in range(len(data_table)):
        for combo in itertools.combinations(data_table.listed_vals[row_num], 2):
            segments_to_check = CheckLeaf(combo[0],combo[1])
            if segments_to_check.on_screen() and segments_to_check.line_segments_intersect() and segments_to_check.calc_angle_between_segments() > 80.0:
                df = df.append([[data_table.classification_id[row_num], \
                                 data_table.user_name[row_num], \
                                 data_table.created_at[row_num], \
                                 data_table.subject_data[row_num], \
                                 data_table.subject_ids[row_num], \
                                 segments_to_check.calc_angle_between_segments(), \
                                 segments_to_check.calc_lengths_minor_major()[0], \
                                 segments_to_check.calc_lengths_minor_major()[1][0], \
                                 segments_to_check.calc_lengths_minor_major()[1][1], \
                                 segments_to_check.calc_lengths_minor_major()[1][2], \
                                 segments_to_check.calc_lengths_minor_major()[1][3], \
                                 segments_to_check.calc_lengths_minor_major()[2], \
                                 segments_to_check.calc_lengths_minor_major()[3][0], \
                                 segments_to_check.calc_lengths_minor_major()[3][1], \
                                 segments_to_check.calc_lengths_minor_major()[3][2], \
                                 segments_to_check.calc_lengths_minor_major()[3][2]]]) 

    df = df.rename({0: 'classification_id', \
